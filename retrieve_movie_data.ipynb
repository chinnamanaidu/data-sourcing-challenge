# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json

# %%
# Set environment variables from the .env in the local environment
load_dotenv()

nyt_api_key = os.getenv("NYT_API_KEY")
tmdb_api_key = os.getenv("TMDB_API_KEY")
nyt_api_key
tmdb_api_key
# Out:
# 'ccec75fed17f3e583deaf2eba372eba8'

# %% [markdown]
# ### Access the New York Times API

# %%
# Set the base URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"
filter_query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'

# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

# Build URL
#query_url = url + "fq=" + filter_query + "&fl=" + field_list + "&begin_date=" + begin_date + "&end_date=" + end_date+ "&api-key=" + nyt_api_key
query_url = (
    f"{url}api-key={nyt_api_key}&begin_date={begin_date}&end_date={end_date}"
    + f'&fq={filter_query}&sort={sort}&fl={field_list}'
)
print(query_url)
#articles = requests.get(query_url).json()
#reviews_list  = articles["response"]["docs"]
#reviews_list
#print(json.dumps(articles, indent=4))
# Out:
# https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=zQuU5XlAfdZ7MGB8MkGdmAkvGK5lIEt4&begin_date=20130101&end_date=20230531&fq=section_name:"Movies" AND type_of_material:"Review" AND headline:"love"&sort=newest&fl=headline,web_url,snippet,source,keywords,pub_date,byline,word_count

# %%
# Create an empty list to store the reviews


# loop through pages 0-19

    # create query with a page number
    # API results show 10 articles at a time

    
    # Make a "GET" request and retrieve the JSON

    
    # Add a twelve second interval between queries to stay within API query limits

    
    # Try and save the reviews to the reviews_list

        # loop through the reviews["response"]["docs"] and append each review to the list

        # Print the page that was just retrieved


        # Print the page number that had no results then break from the loop
        
reviews=[]
reviews_df= pd.Series()
for i in range(20):    
    i=i+1
    query_url = (
    f"{url}api-key={nyt_api_key}&begin_date={begin_date}&end_date={end_date}"
    + f'&fq={filter_query}&sort={sort}&fl={field_list}&page='+str(i)
    )
    try:
        #query_url = url + "fq=" + filter_query + "&fl=" + field_list + "&begin_date=" + begin_date + "&end_date=" + end_date+ "&page="+str(i)+"&api-key=" + nyt_api_key
        articles = requests.get(query_url).json()
        time.sleep(12)
        reviews_list  = articles["response"]["docs"] 
        print(json.dumps(reviews_list, indent=4))        
        print("Checked page ", i-1)
        reviews.append(reviews_list)
    except:
        print ("Checked Page no data ", i)
# Out:
# [
#     {
#         "web_url": "https://www.nytimes.com/2023/01/31/movies/pamela-a-love-story-review.html",
#         "snippet": "This documentary from Ryan White rewinds, to powerful effect, on Pamela Anderson\u2019s life and fame.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Pamela, a Love Story\u2019 Review: A Frank Look Back",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Pamela, a Love Story",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Documentary Films and Programs",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Anderson, Pamela (1967- )",
#                 "rank": 2,
#                 "major": "N"
# ...

# %%
#Print top 5 movies list data
print(json.dumps(reviews[1][0:4], indent=4))
# Out:
# [
#     {
#         "web_url": "https://www.nytimes.com/2022/09/08/movies/about-fate-review.html",
#         "snippet": "Thomas Mann\u2019s beguiling performance drives this Emma Roberts vehicle, but the romantic comedy creaks under the weight of its coincidences.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018About Fate\u2019 Review: Love the One You\u2019re With?",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "About Fate",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "About Fate (Movie)",
#                 "rank": 2,
#                 "major": "N"
# ...

# %%
#converting to data frame
review_results2 = pd.Series()
for i in range(20):
    review_results1 = pd.json_normalize(reviews[i])
    review_results2  = pd.concat([review_results2,review_results1])
review_results2.reset_index()
# Out:
#      index    0                                            web_url  \
# 0        0  NaN  https://www.nytimes.com/2023/01/31/movies/pame...
# 1        1  NaN  https://www.nytimes.com/2023/01/19/movies/in-f...
# 2        2  NaN  https://www.nytimes.com/2023/01/19/movies/afte...
# 3        3  NaN  https://www.nytimes.com/2023/01/05/movies/alca...
# 4        4  NaN  https://www.nytimes.com/2022/12/15/movies/nell...
# ..     ...  ...                                                ...
# 195      5  NaN  https://www.nytimes.com/2016/12/08/movies/fran...
# 196      6  NaN  https://www.nytimes.com/2016/11/22/movies/alli...
# 197      7  NaN  https://www.nytimes.com/2016/11/18/movies/revi...
# 198      8  NaN  https://www.nytimes.com/2016/11/18/movies/ali-...
# 199      9  NaN  https://www.nytimes.com/2016/11/04/movies/lovi...
#
#                                                snippet              source  \
# 0    This documentary from Ryan White rewinds, to p...  The New York Times
# ...

# %%
# Extract 'name' and 'value' from items in "keywords" column
def extract_keywords(keyword_list):
    extracted_keywords = ""
    for item in keyword_list:
        # Extract 'name' and 'value'
        try:
            keyword = f"{item['name']}: {item['value']};" 
            # Append the keyword item to the extracted_keywords list
            extracted_keywords += keyword
        except:
            print(" the data not parsable")
    return extracted_keywords
review_results2["keywords"] = review_results2["keywords"].apply(extract_keywords)
review_results2
# Fix the "keywords" column by converting cells from a list to a string
# Out:
#       0                                            web_url  \
# 0   NaN  https://www.nytimes.com/2023/01/31/movies/pame...
# 1   NaN  https://www.nytimes.com/2023/01/19/movies/in-f...
# 2   NaN  https://www.nytimes.com/2023/01/19/movies/afte...
# 3   NaN  https://www.nytimes.com/2023/01/05/movies/alca...
# 4   NaN  https://www.nytimes.com/2022/12/15/movies/nell...
# ..  ...                                                ...
# 5   NaN  https://www.nytimes.com/2016/12/08/movies/fran...
# 6   NaN  https://www.nytimes.com/2016/11/22/movies/alli...
# 7   NaN  https://www.nytimes.com/2016/11/18/movies/revi...
# 8   NaN  https://www.nytimes.com/2016/11/18/movies/ali-...
# 9   NaN  https://www.nytimes.com/2016/11/04/movies/lovi...
#
#                                               snippet              source  \
# 0   This documentary from Ryan White rewinds, to p...  The New York Times
# 1   In Matt Carter’s gay rugby film, sports and ro...  The New York Times
# ...

# %%
# Create a list from the "title" column using to_list()
# These titles will be used in the query for The Movie Database
#review_results4["title"]=review_results4["headline.main"]
review_results2["title"] = review_results2["headline.main"].apply(lambda st: st[st.find("\u2018")+1:st.find("\u2019 Review")])
review_results2["title"].to_list()
# Out:
# ['Pamela, a Love Story',
#  'In From the Side',
#  'After Love',
#  'Alcarràs',
#  'Nelly & Nadine',
#  'Lady Chatterley’s Lover',
#  'The Sound of Christmas',
#  'The Inspection',
#  'Bones and All',
#  'My Policeman',
#  'About Fate',
#  'Waiting for Bojangles',
#  'I Love My Dad',
#  'A Love Song',
#  'Alone Together',
#  'Art of Love',
#  'The Wheel',
#  'Thor: Love and Thunder',
#  'Both Sides of the Blade',
#  'Fire of Love',
#  'Love & Gelato',
#  'Stay Prayed Up',
#  'Benediction',
#  'Dinner in America',
#  'In a New York Minute',
#  'Anaïs in Love',
#  'I Love America',
#  'See You Then',
#  'La Mami',
#  'Love After Love',
#  'Deep Water',
#  'Lucy and Desi',
#  'Cyrano',
#  'The In Between',
#  'Book of Love',
#  'Lingui, the Sacred Bonds',
#  'The Pink Cloud',
#  'A Journal for Jordan',
#  'West Side Story',
#  'Aulcie',
#  'Love Is Love Is Love',
#  'Love Hard',
#  'Bergman Island',
#  'Hard Luck Love Song',
#  'South of Heaven',
#  'Wife of a Spy',
# ...

# %%
reviews[0][0]["keywords"]
# Out:
# [{'name': 'subject',
#   'value': 'Documentary Films and Programs',
#   'rank': 1,
#   'major': 'N'},
#  {'name': 'persons',
#   'value': 'Anderson, Pamela (1967- )',
#   'rank': 2,
#   'major': 'N'},
#  {'name': 'persons',
#   'value': 'White, Ryan (Filmmaker)',
#   'rank': 3,
#   'major': 'N'},
#  {'name': 'creative_works',
#   'value': 'Pamela, a Love Story (Movie)',
#   'rank': 4,
#   'major': 'N'}]

# %% [markdown]
# ### Access The Movie Database API

# %%
url = "https://api.themoviedb.org/3/search/movie?query="
tmdb_key_string = "&api_key=" + tmdb_api_key
tmdb_key_string
# Out:
# '&api_key=ccec75fed17f3e583deaf2eba372eba8'

# %%
# Prepare The Movie Database query
url = "https://api.themoviedb.org/3/search/movie?query="
tmdb_key_string = "&api_key=" + tmdb_api_key

# %%
# Create an empty list to store the results


# Create a request counter to sleep the requests after a multiple
# of 50 requests


# Loop through the titles

    # Check if we need to sleep before making a request


    # Add 1 to the request counter

    
    # Perform a "GET" request for The Movie Database


    # Include a try clause to search for the full movie details.
    # Use the except clause to print out a statement if a movie
    # is not found.

        # Get movie id


        # Make a request for a the full movie details


        # Execute "GET" request with url

        
        # Extract the genre names into a list


        # Extract the spoken_languages' English name into a list


        # Extract the production_countries' name into a list


        # Add the relevant data to a dictionary and
        # append it to the tmdb_movies_list list

        
        # Print out the title that was found
titles=[]
review_results5 =review_results2
for i in review_results5["title"].to_list():
    query_url = url +  i +"&api_key=" + tmdb_api_key
    try:
        moviesList = requests.get(query_url).json()
        time.sleep(10) 
        try:
            print("MovieId ", moviesList["results"][0]["id"])
            movieId = moviesList["results"][0]["id"]
            response_data = requests.get('https://api.themoviedb.org/3/movie/'+str(movieId)+'?api_key=' +  tmdb_api_key).json()
            print("Found ", i)
            titles.append(response_data)
        except:
            print(" not found ", i)
    except:
        print("Not Found ", i)
titles
# Out:
# MovieId  1061671
# Found  Pamela, a Love Story
# MovieId  622082
# Found  In From the Side
# MovieId  714011
# Found  After Love
# MovieId  804251
# Found  Alcarràs
# MovieId  12652
# Found  Nelly & Nadine
# MovieId  814338
# Found  Lady Chatterley’s Lover
# MovieId  1035923
# Found  The Sound of Christmas
# MovieId  837938
# Found  The Inspection
# MovieId  791177
# Found  Bones and All
# MovieId  744114
# Found  My Policeman
# MovieId  828613
# Found  About Fate
# MovieId  851303
# Found  Waiting for Bojangles
# MovieId  876825
# Found  I Love My Dad
# MovieId  913851
# Found  A Love Song
# MovieId  826113
# Found  Alone Together
# MovieId  1248795
# Found  Art of Love
# MovieId  630737
# Found  The Wheel
# MovieId  616037
# Found  Thor: Love and Thunder
# MovieId  768757
# Found  Both Sides of the Blade
# MovieId  913823
# Found  Fire of Love
# MovieId  1248795
# Found  Love & Gelato
# MovieId  869628
# Found  Stay Prayed Up
# MovieId  399178
# Found  Benediction
# ...

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
titles[0:5]
print(json.dumps(titles[0:5], indent=4))
# Out:
# [
#     {
#         "adult": false,
#         "backdrop_path": "/aJvgoRMrYFTMu7MrcfxYVPMRuU5.jpg",
#         "belongs_to_collection": null,
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 99,
#                 "name": "Documentary"
#             }
#         ],
#         "homepage": "https://www.netflix.com/title/81590934",
#         "id": 1061671,
#         "imdb_id": "tt18376122",
#         "origin_country": [
#             "US"
#         ],
#         "original_language": "en",
#         "original_title": "Pamela, A Love Story",
#         "overview": "In her own words, through personal video and diaries, Pamela Anderson shares the story of her rise to fame, rocky romances and infamous sex tape scandal.",
#         "popularity": 26.916,
#         "poster_path": "/zkVnRwZWbrd55P3Tx7BZZQ1gU89.jpg",
#         "production_companies": [
#             {
#                 "id": 90561,
#                 "logo_path": null,
# ...

# %%
# Convert the results to a DataFrame
moview_review_df = pd.DataFrame(titles)
required_df=moview_review_df[["title","original_title","budget","genres","original_language","spoken_languages","homepage","overview","popularity","runtime","revenue","release_date","vote_average","vote_count","production_countries"]]
required_df
# Out:
#                          title                    original_title    budget  \
# 0         Pamela, A Love Story              Pamela, A Love Story         0
# 1             In from the Side                  In from the Side         0
# 2                   After Love                        After Love         0
# 3                     Alcarràs                          Alcarràs         3
# 4    Nelly and Monsieur Arnaud               Nelly et Mr. Arnaud         0
# ..                         ...                               ...       ...
# 142             The Other Half                    The Other Half         0
# 143     The Ottoman Lieutenant            The Ottoman Lieutenant  40000000
# 144                Art of Love                   Romantik Hırsız         0
# 145  Paris 05:59 / Théo & Hugo  Théo et Hugo dans le même bateau         0
# 146  My Best Friend Anne Frank    Mijn beste vriendin Anne Frank         0
#
# ...

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Merge the New York Times reviews and TMDB DataFrames on title
merge_df = pd.merge(required_df, review_results2, on="title")
merge_df
# Out:
#                       title          original_title    budget  \
# 0                After Love              After Love         0
# 1                After Love    L'économie du couple         0
# 2                  Alcarràs                Alcarràs         3
# 3    The Sound of Christmas  The Sound of Christmas         0
# 4            The Inspection          The Inspection         0
# ..                      ...                     ...       ...
# 116    In Search of Fellini    In Search of Fellini         0
# 117           The Last Face           The Last Face         0
# 118           Lost in Paris         Paris pieds nus         0
# 119          The Other Half          The Other Half         0
# 120  The Ottoman Lieutenant  The Ottoman Lieutenant  40000000
#
#                                                 genres original_language  \
# 0                        [{'id': 18, 'name': 'Drama'}]                en
# ...

# %%
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing


# Create a list of characters to remove


# Loop through the list of columns to fix

    # Convert the column to type 'str'


    # Loop through characters to remove

def replace_string(strToReplace):
    strToReplace = str(strToReplace).replace(']', '')
    strToReplace = str(strToReplace).replace('', '')
    return str(strToReplace).replace('[', '')

merge_df["genres"]=merge_df["genres"].apply(replace_string)
merge_df["spoken_languages"]=merge_df["spoken_languages"].apply(replace_string)
merge_df["production_countries"]=merge_df["production_countries"].apply(replace_string)
merge_df
# Display the fixed DataFrame
# Out:
#                       title          original_title    budget  \
# 0                After Love              After Love         0
# 1                After Love    L'économie du couple         0
# 2                  Alcarràs                Alcarràs         3
# 3    The Sound of Christmas  The Sound of Christmas         0
# 4            The Inspection          The Inspection         0
# ..                      ...                     ...       ...
# 116    In Search of Fellini    In Search of Fellini         0
# 117           The Last Face           The Last Face         0
# 118           Lost in Paris         Paris pieds nus         0
# 119          The Other Half          The Other Half         0
# 120  The Ottoman Lieutenant  The Ottoman Lieutenant  40000000
#
#                                                 genres original_language  \
# 0                          {'id': 18, 'name': 'Drama'}                en
# ...

# %%
# Drop "byline.person" column
merge_df=merge_df.drop(columns=['byline.person'])
merge_df
# Out:
#                       title          original_title    budget  \
# 0                After Love              After Love         0
# 1                After Love    L'économie du couple         0
# 2                  Alcarràs                Alcarràs         3
# 3    The Sound of Christmas  The Sound of Christmas         0
# 4            The Inspection          The Inspection         0
# ..                      ...                     ...       ...
# 116    In Search of Fellini    In Search of Fellini         0
# 117           The Last Face           The Last Face         0
# 118           Lost in Paris         Paris pieds nus         0
# 119          The Other Half          The Other Half         0
# 120  The Ottoman Lieutenant  The Ottoman Lieutenant  40000000
#
#                                                 genres original_language  \
# 0                          {'id': 18, 'name': 'Drama'}                en
# ...

# %%
# Delete duplicate rows and reset index
merge_df.drop_duplicates()
merge_df
# Out:
#                       title          original_title    budget  \
# 0                After Love              After Love         0
# 1                After Love    L'économie du couple         0
# 2                  Alcarràs                Alcarràs         3
# 3    The Sound of Christmas  The Sound of Christmas         0
# 4            The Inspection          The Inspection         0
# ..                      ...                     ...       ...
# 116    In Search of Fellini    In Search of Fellini         0
# 117           The Last Face           The Last Face         0
# 118           Lost in Paris         Paris pieds nus         0
# 119          The Other Half          The Other Half         0
# 120  The Ottoman Lieutenant  The Ottoman Lieutenant  40000000
#
#                                                 genres original_language  \
# 0                          {'id': 18, 'name': 'Drama'}                en
# ...

# %%
# Export data to CSV without the index
merge_df.to_csv("output/dataoutput.csv", index=False, header=True)
